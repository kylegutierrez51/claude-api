# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024 # number of tokens used in thinking portion. "max_tokens" must be greater than your thinking budget
):
    params = {
        "model": model,
        "max_tokens": 2000, # remaining 976 tokens allocated to generating text
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a one paragraph guide to recursion")

chat(messages, thinking=True)
# Out:
# Message(id='msg_01AHqfJKBBDFWnxtBZfRJ6sG', container=None, content=[ThinkingBlock(signature='...', thinking="This is a fun prompt about recursion, and there's a classic joke opportunity here where I could make the guide recursive by having it refer back to itself. Let me write a helpful, clear paragraph that explains recursion well, and I might subtly incorporate the self-referential humor that's traditional with recursion explanations.\n\nLet me write a straightforward, informative paragraph:", type='thinking'), TextBlock(citations=None, text="Recursion is a programming technique where a function solves a problem by calling itself with a smaller or simpler version of the same problem, continuing until it reaches a base case that can be solved directly without further recursive calls. To write a recursive function, you need two essential components: (1) a base case that stops the recursion and returns a value without making another recursive call, and (2) a recursive case that breaks
# ...

# %%
# force back a redacted thinking block using the variable "thinking_test_str", which guarantees back a redacted thinking block

# However, it doesn't work. So just view the video "Extended Thinking" on the anthropic.skilljar course: "Building With Claude"
add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_01HQvyYRk1tUKwh2rWc5Qyft', container=None, content=[ThinkingBlock(signature='...', thinking='This is a straightforward request asking me to write a one paragraph guide to recursion. This is a common computer science concept, and I should provide a clear, helpful explanation.\n\nRecursion is when a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. I should explain:\n1. What recursion is\n2. Key components (base case and recursive case)\n3. How it works\n4. Maybe a simple example\n\nLet me write a clear, concise paragraph.', type='thinking'), TextBlock(citations=None, text="# A Guide to Recursion\n\nRecursion is a programming technique where a function solves a problem by calling itself with modified inputs, breaking down complex problems into simpler, self-similar subproblems. Every recursive function needs two essential components: a **base case** that stops the recursion (without it, the function would call itself infinit
# ...
